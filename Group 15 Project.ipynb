# %%
import numpy as np
import pandas as pd

# %%
DataWorld = pd.read_csv("Crops_AllData_Normalized.csv", encoding = 'cp1252')

# %%
DataWorld
# Out:
#          Area Code                                     Area  Item Code  \
# 0                2                              Afghanistan        221
# 1                2                              Afghanistan        221
# 2                2                              Afghanistan        221
# 3                2                              Afghanistan        221
# 4                2                              Afghanistan        221
# ...            ...                                      ...        ...
# 2513863       5817  Net Food Importing Developing Countries       1735
# 2513864       5817  Net Food Importing Developing Countries       1735
# 2513865       5817  Net Food Importing Developing Countries       1735
# 2513866       5817  Net Food Importing Developing Countries       1735
# 2513867       5817  Net Food Importing Developing Countries       1735
#
#                         Item  Element Code         Element  Year Code  Year  \
# ...

# %% [markdown]
# ### Drop the unneeded columns

# %%
DataWorld.drop(["Area Code", "Item Code", "Element Code", "Year Code", "Flag"], inplace = True, axis = 1)

# %%
DataWorld
# Out:
#                                             Area                 Item  \
# 0                                    Afghanistan  Almonds, with shell
# 1                                    Afghanistan  Almonds, with shell
# 2                                    Afghanistan  Almonds, with shell
# 3                                    Afghanistan  Almonds, with shell
# 4                                    Afghanistan  Almonds, with shell
# ...                                          ...                  ...
# 2513863  Net Food Importing Developing Countries   Vegetables Primary
# 2513864  Net Food Importing Developing Countries   Vegetables Primary
# 2513865  Net Food Importing Developing Countries   Vegetables Primary
# 2513866  Net Food Importing Developing Countries   Vegetables Primary
# 2513867  Net Food Importing Developing Countries   Vegetables Primary
#
#                 Element  Year    Unit       Value
# 0        Area harvested  1975      ha         0.0
# ...

# %% [markdown]
# ### Filter the data to show only the production value of each crop

# %%
DataWorld_Production = DataWorld.loc[DataWorld.Element == "Production"]

# %%
DataWorld_Production
# Out:
#                                             Area                 Item  \
# 89                                   Afghanistan  Almonds, with shell
# 90                                   Afghanistan  Almonds, with shell
# 91                                   Afghanistan  Almonds, with shell
# 92                                   Afghanistan  Almonds, with shell
# 93                                   Afghanistan  Almonds, with shell
# ...                                          ...                  ...
# 2513863  Net Food Importing Developing Countries   Vegetables Primary
# 2513864  Net Food Importing Developing Countries   Vegetables Primary
# 2513865  Net Food Importing Developing Countries   Vegetables Primary
# 2513866  Net Food Importing Developing Countries   Vegetables Primary
# 2513867  Net Food Importing Developing Countries   Vegetables Primary
#
#             Element  Year    Unit       Value
# 89       Production  1975  tonnes         0.0
# ...

# %% [markdown]
# ### Filter the data to show only data on crops in Nigeria

# %%
DataWorld_Nig = DataWorld_Production.loc[DataWorld.Area == "Nigeria"]

# %%
DataWorld_Nig
# Out:
#             Area                Item     Element  Year    Unit       Value
# 1184326  Nigeria   Bastfibres, other  Production  1981  tonnes       530.0
# 1184327  Nigeria   Bastfibres, other  Production  1982  tonnes       500.0
# 1184328  Nigeria   Bastfibres, other  Production  1983  tonnes       500.0
# 1184329  Nigeria   Bastfibres, other  Production  1984  tonnes       550.0
# 1184330  Nigeria   Bastfibres, other  Production  1985  tonnes       600.0
# ...          ...                 ...         ...   ...     ...         ...
# 1194879  Nigeria  Vegetables Primary  Production  2015  tonnes  16187140.0
# 1194880  Nigeria  Vegetables Primary  Production  2016  tonnes  14495945.0
# 1194881  Nigeria  Vegetables Primary  Production  2017  tonnes  15068458.0
# 1194882  Nigeria  Vegetables Primary  Production  2018  tonnes  16058522.0
# 1194883  Nigeria  Vegetables Primary  Production  2019  tonnes  16670642.0
#
# [3670 rows x 6 columns]

# %% [markdown]
# ### Find out which of the columns has missing value

# %%
# Its being discovered that column "Value" has missing values

DataWorld_Nig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3670 entries, 1184326 to 1194883
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Area     3670 non-null   object
#  1   Item     3670 non-null   object
#  2   Element  3670 non-null   object
#  3   Year     3670 non-null   int64
#  4   Unit     3670 non-null   object
#  5   Value    3547 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 200.7+ KB

# %% [markdown]
# ### How many missing values are in column "Value"

# %%
# column "Value" has 123 missing values

DataWorld_Nig.isnull().sum()
# Out:
# Area         0
# Item         0
# Element      0
# Year         0
# Unit         0
# Value      123
# dtype: int64

# %% [markdown]
# ### Dropping the rows having missing values

# %%
DataWorld_Nig.dropna(inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13084\1301464028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DataWorld_Nig.dropna(inplace = True)

# %%
DataWorld_Nig
# Out:
#             Area                Item     Element  Year    Unit       Value
# 1184326  Nigeria   Bastfibres, other  Production  1981  tonnes       530.0
# 1184327  Nigeria   Bastfibres, other  Production  1982  tonnes       500.0
# 1184328  Nigeria   Bastfibres, other  Production  1983  tonnes       500.0
# 1184329  Nigeria   Bastfibres, other  Production  1984  tonnes       550.0
# 1184330  Nigeria   Bastfibres, other  Production  1985  tonnes       600.0
# ...          ...                 ...         ...   ...     ...         ...
# 1194879  Nigeria  Vegetables Primary  Production  2015  tonnes  16187140.0
# 1194880  Nigeria  Vegetables Primary  Production  2016  tonnes  14495945.0
# 1194881  Nigeria  Vegetables Primary  Production  2017  tonnes  15068458.0
# 1194882  Nigeria  Vegetables Primary  Production  2018  tonnes  16058522.0
# 1194883  Nigeria  Vegetables Primary  Production  2019  tonnes  16670642.0
#
# [3547 rows x 6 columns]

# %%
# Removing rows with value = 0.0

DataWorld_Nigeria = DataWorld_Nig[DataWorld_Nig.apply(lambda x:x["Value"] != 0.0, axis = 1)]

# %%
DataWorld_Nigeria
# Out:
#             Area                Item     Element  Year    Unit       Value
# 1184326  Nigeria   Bastfibres, other  Production  1981  tonnes       530.0
# 1184327  Nigeria   Bastfibres, other  Production  1982  tonnes       500.0
# 1184328  Nigeria   Bastfibres, other  Production  1983  tonnes       500.0
# 1184329  Nigeria   Bastfibres, other  Production  1984  tonnes       550.0
# 1184330  Nigeria   Bastfibres, other  Production  1985  tonnes       600.0
# ...          ...                 ...         ...   ...     ...         ...
# 1194879  Nigeria  Vegetables Primary  Production  2015  tonnes  16187140.0
# 1194880  Nigeria  Vegetables Primary  Production  2016  tonnes  14495945.0
# 1194881  Nigeria  Vegetables Primary  Production  2017  tonnes  15068458.0
# 1194882  Nigeria  Vegetables Primary  Production  2018  tonnes  16058522.0
# 1194883  Nigeria  Vegetables Primary  Production  2019  tonnes  16670642.0
#
# [3527 rows x 6 columns]

# %%
# The missing/null valuesin column "Value" have being removed

DataWorld_Nigeria.isnull().sum()
# Out:
# Area       0
# Item       0
# Element    0
# Year       0
# Unit       0
# Value      0
# dtype: int64

# %% [markdown]
# ### Resetting the index of the data

# %%
DataWorld_Nigeria.reset_index(inplace = True)

# %%
DataWorld_Nigeria
# Out:
#         index     Area                Item     Element  Year    Unit  \
# 0     1184326  Nigeria   Bastfibres, other  Production  1981  tonnes
# 1     1184327  Nigeria   Bastfibres, other  Production  1982  tonnes
# 2     1184328  Nigeria   Bastfibres, other  Production  1983  tonnes
# 3     1184329  Nigeria   Bastfibres, other  Production  1984  tonnes
# 4     1184330  Nigeria   Bastfibres, other  Production  1985  tonnes
# ...       ...      ...                 ...         ...   ...     ...
# 3522  1194879  Nigeria  Vegetables Primary  Production  2015  tonnes
# 3523  1194880  Nigeria  Vegetables Primary  Production  2016  tonnes
# 3524  1194881  Nigeria  Vegetables Primary  Production  2017  tonnes
# 3525  1194882  Nigeria  Vegetables Primary  Production  2018  tonnes
# 3526  1194883  Nigeria  Vegetables Primary  Production  2019  tonnes
#
#            Value
# 0          530.0
# 1          500.0
# 2          500.0
# 3          550.0
# 4          600.0
# ...          ...
# ...

# %%
DataWorld_Nigeria.to_csv("DataWorld_Nigeria.csv")

# %% [markdown]
# ## Import the Population Data

# %%
World_Pop = pd.read_csv("Total_Population_All_Countries.csv", encoding = "cp1252")

# %%
World_Pop
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0           4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1           4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2           4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3           4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4           4  Afghanistan      2       Medium  1954     1954.5   4266.484
# ...       ...          ...    ...          ...   ...        ...        ...
# 280927    716     Zimbabwe    207  Lower 95 PI  2080     2080.5  10576.533
# 280928    716     Zimbabwe    207  Lower 95 PI  2085     2085.5  10293.349
# 280929    716     Zimbabwe    207  Lower 95 PI  2090     2090.5   9920.336
# 280930    716     Zimbabwe    207  Lower 95 PI  2095     2095.5   9503.711
# 280931    716     Zimbabwe    207  Lower 95 PI  2100     2100.5   9090.075
#
#         PopFemale   PopTotal  PopDensity
# ...

# %% [markdown]
# ### Filter the Population Data to reveal only the data for Nigeria

# %%
World_Pop_Nig = World_Pop.loc[World_Pop.Location == "Nigeria"]

# %%
World_Pop_Nig
# Out:
#         LocID Location  VarID      Variant  Time  MidPeriod     PopMale  \
# 178728    566  Nigeria      2       Medium  1950     1950.5   18886.354
# 178729    566  Nigeria      2       Medium  1951     1951.5   19167.315
# 178730    566  Nigeria      2       Medium  1952     1952.5   19472.357
# 178731    566  Nigeria      2       Medium  1953     1953.5   19797.568
# 178732    566  Nigeria      2       Medium  1954     1954.5   20140.076
# ...       ...      ...    ...          ...   ...        ...         ...
# 179607    566  Nigeria    207  Lower 95 PI  2080     2080.5  178932.698
# 179608    566  Nigeria    207  Lower 95 PI  2085     2085.5  176290.374
# 179609    566  Nigeria    207  Lower 95 PI  2090     2090.5  171242.240
# 179610    566  Nigeria    207  Lower 95 PI  2095     2095.5  165388.849
# 179611    566  Nigeria    207  Lower 95 PI  2100     2100.5  159669.235
#
#          PopFemale    PopTotal  PopDensity
# 178728   18973.396   37859.750      41.569
# ...

# %% [markdown]
# ## Drop Unneeded Columns

# %%
Drop_Col = ["LocID","VarID","MidPeriod","PopMale","PopFemale"]

World_Pop_Nig.drop(Drop_Col, inplace = True, axis = 1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13084\2453309265.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   World_Pop_Nig.drop(Drop_Col, inplace = True, axis = 1)

# %%
World_Pop_Nig
# Out:
#        Location      Variant  Time    PopTotal  PopDensity
# 178728  Nigeria       Medium  1950   37859.750      41.569
# 178729  Nigeria       Medium  1951   38424.142      42.189
# 178730  Nigeria       Medium  1952   39035.435      42.860
# 178731  Nigeria       Medium  1953   39686.159      43.574
# 178732  Nigeria       Medium  1954   40370.853      44.326
# ...         ...          ...   ...         ...         ...
# 179607  Nigeria  Lower 95 PI  2080  357568.275     392.600
# 179608  Nigeria  Lower 95 PI  2085  352594.794     387.139
# 179609  Nigeria  Lower 95 PI  2090  343801.722     377.485
# 179610  Nigeria  Lower 95 PI  2095  332706.091     365.302
# 179611  Nigeria  Lower 95 PI  2100  322064.203     353.617
#
# [884 rows x 5 columns]

# %% [markdown]
# ## Data between 1981 and 2019

# %%
World_Pop_Nig1 = World_Pop_Nig.loc[(World_Pop_Nig.Time > 1980) & (World_Pop_Nig.Time < 2020)]

# %%
World_Pop_Nig1.head()
# Out:
#        Location Variant  Time   PopTotal  PopDensity
# 178759  Nigeria  Medium  1981  75440.505      82.832
# 178760  Nigeria  Medium  1982  77427.539      85.013
# 178761  Nigeria  Medium  1983  79414.841      87.195
# 178762  Nigeria  Medium  1984  81448.757      89.428
# 178763  Nigeria  Medium  1985  83562.776      91.750

# %% [markdown]
# ### Resetting the index

# %%
World_Pop_Nig1.reset_index(inplace = True)

# %%
World_Pop_Nig1.head()
# Out:
#     index Location Variant  Time   PopTotal  PopDensity
# 0  178759  Nigeria  Medium  1981  75440.505      82.832
# 1  178760  Nigeria  Medium  1982  77427.539      85.013
# 2  178761  Nigeria  Medium  1983  79414.841      87.195
# 3  178762  Nigeria  Medium  1984  81448.757      89.428
# 4  178763  Nigeria  Medium  1985  83562.776      91.750

# %% [markdown]
# ### Checking for null/missing Values

# %%
# No missing/null values

World_Pop_Nig1.isnull().sum()
# Out:
# index         0
# Location      0
# Variant       0
# Time          0
# PopTotal      0
# PopDensity    0
# dtype: int64

# %%
World_Pop_Nig1.to_csv("Nig_Population.csv")
